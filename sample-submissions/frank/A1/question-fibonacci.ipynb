# %% [markdown]
# # Assignment A1\nSolve the programming task.\n

# %%
def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n - 1)

print(factorial(8))

# %%
# helper cell not graded\npass\n
