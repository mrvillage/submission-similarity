# %% [markdown]
# # Assignment A1\nSolve the programming task.\n

# %%
# copied-and-edited style variant
def build_sequence(n):
    a,b = 0,1
    out=[]
    for i in range(n):
        out.append(a)
        a,b = b,a+b
    return out
print(build_sequence(10))

# %%
# helper cell not graded\npass\n
